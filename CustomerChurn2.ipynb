# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer_churn.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churned, notchurned = df[df['Churn'] == 'Yes']['Churn'].count(), df[df['Churn'] == 'No']['Churn'].count()
print("Churned:", churned)
print("Not Churned:", notchurned)
# Out:
# Churned: 1869
# Not Churned: 5174

# %%
import matplotlib.pyplot as plt
import seaborn as sns

size = [churned, notchurned]
labels = ['Churned', 'Not Churned']

plt.pie(size, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(df['InternetService'])
plt.title('Internet Service',size=18)
plt.xlabel('Internet Services',size=14)
plt.ylabel('Count',size=14)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
malecount = df[df['gender'] == 'Male']['gender'].count()
print("Male Count: ",malecount)
# Out:
# Male Count:  3555

# %%
dsl = df[df['InternetService'] == 'DSL']['InternetService'].count()
print(dsl)
# Out:
# 2421

# %%
# new_customer = df[df['PaymentMethod'] == 'Mailed check']['PaymentMethod'].count()
new_customer = df[df['PaymentMethod'].str.contains('^Mailed', regex=True)]['PaymentMethod'].count()
print(new_customer)
# Out:
# 1612

# %%
customer = df[(df['tenure'] <= int(10)) | (df['TotalCharges'] <= float(500))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 customer = df[(df['tenure'] <= int(10)) | (df['TotalCharges'] <= float(500))]
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:52, in OpsMixin.__le__(self, other)
#      50 @unpack_zerodim_and_defer("__le__")
#      51 def __le__(self, other):
# ---> 52     return self._cmp_method(other, operator.le)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
customer
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7035  8456-QDAVC    Male              0      No         No      19
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...
